# %%
weather = pd.read_table('daily_weather.tsv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f5669000c12b> in <module>()
# ----> 1 weather = pd.read_table('daily_weather.tsv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
__
# Out:
# ''

# %%
In [1]:

weather = pd.read_table('daily_weather.tsv')
# Out:
#   File "<ipython-input-4-f862c71ee1f8>", line 1
#     In [1]:
#           ^
# SyntaxError: invalid syntax

# %%
weather = pd.read_table('daily_weather.tsv')

# %%
weather
# Out:
#            date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0    2012-01-01        0            1      Spring           0            0
# 1    2012-01-02        1            1      Spring           1            0
# 2    2012-01-03        2            1      Spring           0            1
# 3    2012-01-04        3            1      Spring           0            1
# 4    2012-01-05        4            1      Spring           0            1
# 5    2012-01-06        5            1      Spring           0            1
# 6    2012-01-07        6            1      Spring           0            0
# 7    2012-01-08        0            1      Spring           0            0
# 8    2012-01-09        1            1      Spring           0            1
# 9    2012-01-10        2            1      Spring           0            1
# 10   2012-01-11        3            1      Spring           0            1
# ...

# %%
type(weather.date)
# Out:
# pandas.core.series.Series

# %%
pd.Series.replace(to_replace=weather.date, value=pd.to_datetime(pd.Series(weather.date)), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-01daf8a0a795> in <module>()
# ----> 1 pd.Series.replace(to_replace=weather.date, value=pd.to_datetime(pd.Series(weather.date)), inplace=True)
#
# TypeError: unbound method replace() must be called with Series instance as first argument (got nothing instead)

# %%
pd.Series.replace(weather.date, pd.to_datetime(pd.Setyries(weather.date)), inplace=True)

# %%
type(weather.date[0])
# Out:
# str

# %%
pd.Series.replace(weather.date, pd.to_datetime(pd.Series(weather.date)))
# Out:
# 0      2012-01-01
# 1      2012-01-02
# 2      2012-01-03
# 3      2012-01-04
# 4      2012-01-05
# 5      2012-01-06
# 6      2012-01-07
# 7      2012-01-08
# 8      2012-01-09
# 9      2012-01-10
# 10     2012-01-11
# 11     2012-01-12
# 12     2012-01-13
# 13     2012-01-14
# 14     2012-01-15
# 15     2012-01-16
# 16     2012-01-17
# 17     2012-01-18
# 18     2012-01-19
# 19     2012-01-20
# 20     2012-01-21
# 21     2012-01-22
# 22     2012-01-23
# 23     2012-01-24
# 24     2012-01-25
# 25     2012-01-26
# 26     2012-01-27
# 27     2012-01-28
# 28     2012-01-29
# 29     2012-01-30
#           ...
# 336    2012-12-02
# 337    2012-12-03
# 338    2012-12-04
# 339    2012-12-05
# 340    2012-12-06
# 341    2012-12-07
# 342    2012-12-08
# 343    2012-12-09
# 344    2012-12-10
# 345    2012-12-11
# 346    2012-12-12
# 347    2012-12-13
# 348    2012-12-14
# 349    2012-12-15
# 350    2012-12-16
# 351    2012-12-17
# 352    2012-12-18
# 353    2012-12-19
# 354    2012-12-20
# ...

# %%
type(weather.date[0])
# Out:
# str

# %%
type(weather.date)
# Out:
# pandas.core.series.Series

# %%
pd.Series.replace(weather.date, method=pd.to_datetime(pd.Series(weather.date)), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-63f854f20b13> in <module>()
# ----> 1 pd.Series.replace(weather.date, method=pd.to_datetime(pd.Series(weather.date)), inplace=True)
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    2734             if isinstance(to_replace, (tuple, list)):
#    2735                 return _single_replace(self, to_replace, method, inplace,
# -> 2736                                        limit)
#    2737
#    2738             if not is_dictlike(to_replace):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _single_replace(self, to_replace, method, inplace, limit)
#      49     orig_dtype = self.dtype
# ...

# %%
type(weather)
# Out:
# pandas.core.frame.DataFrame

# %%
weather.new_date = pd.to_datetime(pd.Series(weather.date))

# %%
weather
# Out:
#            date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0    2012-01-01        0            1      Spring           0            0
# 1    2012-01-02        1            1      Spring           1            0
# 2    2012-01-03        2            1      Spring           0            1
# 3    2012-01-04        3            1      Spring           0            1
# 4    2012-01-05        4            1      Spring           0            1
# 5    2012-01-06        5            1      Spring           0            1
# 6    2012-01-07        6            1      Spring           0            0
# 7    2012-01-08        0            1      Spring           0            0
# 8    2012-01-09        1            1      Spring           0            1
# 9    2012-01-10        2            1      Spring           0            1
# 10   2012-01-11        3            1      Spring           0            1
# ...

# %%
weather['new_date'] = pd.to_datetime(pd.Series(weather.date))

# %%
weather.new_date
# Out:
# 0     2012-01-01
# 1     2012-01-02
# 2     2012-01-03
# 3     2012-01-04
# 4     2012-01-05
# 5     2012-01-06
# 6     2012-01-07
# 7     2012-01-08
# 8     2012-01-09
# 9     2012-01-10
# 10    2012-01-11
# 11    2012-01-12
# 12    2012-01-13
# 13    2012-01-14
# 14    2012-01-15
# 15    2012-01-16
# 16    2012-01-17
# 17    2012-01-18
# 18    2012-01-19
# 19    2012-01-20
# 20    2012-01-21
# 21    2012-01-22
# 22    2012-01-23
# 23    2012-01-24
# 24    2012-01-25
# 25    2012-01-26
# 26    2012-01-27
# 27    2012-01-28
# 28    2012-01-29
# 29    2012-01-30
#          ...
# 336   2012-12-02
# 337   2012-12-03
# 338   2012-12-04
# 339   2012-12-05
# 340   2012-12-06
# 341   2012-12-07
# 342   2012-12-08
# 343   2012-12-09
# 344   2012-12-10
# 345   2012-12-11
# 346   2012-12-12
# 347   2012-12-13
# 348   2012-12-14
# 349   2012-12-15
# 350   2012-12-16
# 351   2012-12-17
# 352   2012-12-18
# 353   2012-12-19
# 354   2012-12-20
# 355   2012-12-21
# 356   2012-12-22
# ...

# %%
weather.new_date[0]
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
weather['date'] = pd.to_datetime(weather['date'])

# %%
weather.date[0]
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
weather.drop('new_date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-487168de8420> in <module>()
# ----> 1 weather.drop('new_date')
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1595                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1596             else:
# -> 1597                 new_axis = axis.drop(labels, errors=errors)
#    1598             dropped = self.reindex(**{axis_name: new_axis})
#    1599             try:
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/index.pyc in drop(self, labels, errors)
#    2568         if mask.any():
#    2569             if errors != 'ignore':
# -> 2570                 raise ValueError('labels %s not contained in axis' % labels[mask])
# ...

# %%
weather.drop('new_date', 1)
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0   2012-01-01        0            1      Spring           0            0
# 1   2012-01-02        1            1      Spring           1            0
# 2   2012-01-03        2            1      Spring           0            1
# 3   2012-01-04        3            1      Spring           0            1
# 4   2012-01-05        4            1      Spring           0            1
# 5   2012-01-06        5            1      Spring           0            1
# 6   2012-01-07        6            1      Spring           0            0
# 7   2012-01-08        0            1      Spring           0            0
# 8   2012-01-09        1            1      Spring           0            1
# 9   2012-01-10        2            1      Spring           0            1
# 10  2012-01-11        3            1      Spring           0            1
# 11  2012-01-12        4            1      Spring           0            1
# ...

# %% [markdown]
# Updated the date column so that it reads as a date and not as a string

# %%
weather.date['2012-03-01':'2012-06-01'][weather.season_desc == 'Spring']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-4e6d50775218> in <module>()
# ----> 1 weather.date['2012-03-01':'2012-06-01'][weather.season_desc == 'Spring']
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     559             key = check_bool_indexer(self.index, key)
#     560
# --> 561         return self._get_with(key)
#     562
#     563     def _get_with(self, key):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/series.pyc in _get_with(self, key)
#     565         if isinstance(key, slice):
#     566             indexer = self.index._convert_slice_indexer(key, kind='getitem')
# --> 567             return self._get_values(indexer)
#     568         elif isinstance(key, ABCDataFrame):
# ...

# %%
weather.date[1:]
# Out:
# 1     2012-01-02
# 2     2012-01-03
# 3     2012-01-04
# 4     2012-01-05
# 5     2012-01-06
# 6     2012-01-07
# 7     2012-01-08
# 8     2012-01-09
# 9     2012-01-10
# 10    2012-01-11
# 11    2012-01-12
# 12    2012-01-13
# 13    2012-01-14
# 14    2012-01-15
# 15    2012-01-16
# 16    2012-01-17
# 17    2012-01-18
# 18    2012-01-19
# 19    2012-01-20
# 20    2012-01-21
# 21    2012-01-22
# 22    2012-01-23
# 23    2012-01-24
# 24    2012-01-25
# 25    2012-01-26
# 26    2012-01-27
# 27    2012-01-28
# 28    2012-01-29
# 29    2012-01-30
# 30    2012-01-31
#          ...
# 336   2012-12-02
# 337   2012-12-03
# 338   2012-12-04
# 339   2012-12-05
# 340   2012-12-06
# 341   2012-12-07
# 342   2012-12-08
# 343   2012-12-09
# 344   2012-12-10
# 345   2012-12-11
# 346   2012-12-12
# 347   2012-12-13
# 348   2012-12-14
# 349   2012-12-15
# 350   2012-12-16
# 351   2012-12-17
# 352   2012-12-18
# 353   2012-12-19
# 354   2012-12-20
# 355   2012-12-21
# 356   2012-12-22
# ...

# %%
weather.date[:1]
# Out:
# 0   2012-01-01
# Name: date, dtype: datetime64[ns]

# %%
weather.date[:60]
# Out:
# 0    2012-01-01
# 1    2012-01-02
# 2    2012-01-03
# 3    2012-01-04
# 4    2012-01-05
# 5    2012-01-06
# 6    2012-01-07
# 7    2012-01-08
# 8    2012-01-09
# 9    2012-01-10
# 10   2012-01-11
# 11   2012-01-12
# 12   2012-01-13
# 13   2012-01-14
# 14   2012-01-15
# 15   2012-01-16
# 16   2012-01-17
# 17   2012-01-18
# 18   2012-01-19
# 19   2012-01-20
# 20   2012-01-21
# 21   2012-01-22
# 22   2012-01-23
# 23   2012-01-24
# 24   2012-01-25
# 25   2012-01-26
# 26   2012-01-27
# 27   2012-01-28
# 28   2012-01-29
# 29   2012-01-30
# 30   2012-01-31
# 31   2012-02-01
# 32   2012-02-02
# 33   2012-02-03
# 34   2012-02-04
# 35   2012-02-05
# 36   2012-02-06
# 37   2012-02-07
# 38   2012-02-08
# 39   2012-02-09
# 40   2012-02-10
# 41   2012-02-11
# 42   2012-02-12
# 43   2012-02-13
# 44   2012-02-14
# 45   2012-02-15
# 46   2012-02-16
# 47   2012-02-17
# 48   2012-02-18
# 49   2012-02-19
# 50   2012-02-20
# 51   2012-02-21
# 52   2012-02-22
# 53   2012-02-23
# 54   2012-02-24
# ...

# %%
weather.date[:60][weather.season_desc == 'Spring']
# Out:
# 0    2012-01-01
# 1    2012-01-02
# 2    2012-01-03
# 3    2012-01-04
# 4    2012-01-05
# 5    2012-01-06
# 6    2012-01-07
# 7    2012-01-08
# 8    2012-01-09
# 9    2012-01-10
# 10   2012-01-11
# 11   2012-01-12
# 12   2012-01-13
# 13   2012-01-14
# 14   2012-01-15
# 15   2012-01-16
# 16   2012-01-17
# 17   2012-01-18
# 18   2012-01-19
# 19   2012-01-20
# 20   2012-01-21
# 21   2012-01-22
# 22   2012-01-23
# 23   2012-01-24
# 24   2012-01-25
# 25   2012-01-26
# 26   2012-01-27
# 27   2012-01-28
# 28   2012-01-29
# 29   2012-01-30
# 30   2012-01-31
# 31   2012-02-01
# 32   2012-02-02
# 33   2012-02-03
# 34   2012-02-04
# 35   2012-02-05
# 36   2012-02-06
# 37   2012-02-07
# 38   2012-02-08
# 39   2012-02-09
# 40   2012-02-10
# 41   2012-02-11
# 42   2012-02-12
# 43   2012-02-13
# 44   2012-02-14
# 45   2012-02-15
# 46   2012-02-16
# 47   2012-02-17
# 48   2012-02-18
# 49   2012-02-19
# 50   2012-02-20
# 51   2012-02-21
# 52   2012-02-22
# 53   2012-02-23
# 54   2012-02-24
# ...

# %%
weather
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0   2012-01-01        0            1      Spring           0            0
# 1   2012-01-02        1            1      Spring           1            0
# 2   2012-01-03        2            1      Spring           0            1
# 3   2012-01-04        3            1      Spring           0            1
# 4   2012-01-05        4            1      Spring           0            1
# 5   2012-01-06        5            1      Spring           0            1
# 6   2012-01-07        6            1      Spring           0            0
# 7   2012-01-08        0            1      Spring           0            0
# 8   2012-01-09        1            1      Spring           0            1
# 9   2012-01-10        2            1      Spring           0            1
# 10  2012-01-11        3            1      Spring           0            1
# 11  2012-01-12        4            1      Spring           0            1
# ...

# %%
weather.date[:60][weather.season_desc == 'Winter']
# Out:
# Series([], Name: date, dtype: datetime64[ns])

# %%
weather
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0   2012-01-01        0            1      Spring           0            0
# 1   2012-01-02        1            1      Spring           1            0
# 2   2012-01-03        2            1      Spring           0            1
# 3   2012-01-04        3            1      Spring           0            1
# 4   2012-01-05        4            1      Spring           0            1
# 5   2012-01-06        5            1      Spring           0            1
# 6   2012-01-07        6            1      Spring           0            0
# 7   2012-01-08        0            1      Spring           0            0
# 8   2012-01-09        1            1      Spring           0            1
# 9   2012-01-10        2            1      Spring           0            1
# 10  2012-01-11        3            1      Spring           0            1
# 11  2012-01-12        4            1      Spring           0            1
# ...

# %%
weather.season_desc[:60] = 'Winter'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather['season_desc'][:60] = 'Winter'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather['season_desc'][df.date == 01.01.2012] = 'Winter'
# Out:
#   File "<ipython-input-35-868ed7ea0166>", line 1
#     weather['season_desc'][df.date == 01.01.2012] = 'Winter'
#                                                ^
# SyntaxError: invalid syntax

# %%
weather.loc[weather.date == 01.01.2012, ['season_desc']] = 'Winter'
# Out:
#   File "<ipython-input-36-8c3ff9003ba0>", line 1
#     weather.loc[weather.date == 01.01.2012, ['season_desc']] = 'Winter'
#                                          ^
# SyntaxError: invalid syntax

# %%
weather.ix[weather.date == 01-01-2012, 'season_desc'] = 'Winter'

# %%
weather
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0   2012-01-01        0            1      Winter           0            0
# 1   2012-01-02        1            1      Winter           1            0
# 2   2012-01-03        2            1      Winter           0            1
# 3   2012-01-04        3            1      Winter           0            1
# 4   2012-01-05        4            1      Winter           0            1
# 5   2012-01-06        5            1      Winter           0            1
# 6   2012-01-07        6            1      Winter           0            0
# 7   2012-01-08        0            1      Winter           0            0
# 8   2012-01-09        1            1      Winter           0            1
# 9   2012-01-10        2            1      Winter           0            1
# 10  2012-01-11        3            1      Winter           0            1
# 11  2012-01-12        4            1      Winter           0            1
# ...

# %%
weather[60:130]
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 60  2012-03-01        4            1      Spring           0            1
# 61  2012-03-02        5            1      Spring           0            1
# 62  2012-03-03        6            1      Spring           0            0
# 63  2012-03-04        0            1      Spring           0            0
# 64  2012-03-05        1            1      Spring           0            1
# 65  2012-03-06        2            1      Spring           0            1
# 66  2012-03-07        3            1      Spring           0            1
# 67  2012-03-08        4            1      Spring           0            1
# 68  2012-03-09        5            1      Spring           0            1
# 69  2012-03-10        6            1      Spring           0            0
# 70  2012-03-11        0            1      Spring           0            0
# 71  2012-03-12        1            1      Spring           0            1
# ...

# %%
weather[50:70]
# Out:
#          date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 50 2012-02-20        1            1      Winter           1            0
# 51 2012-02-21        2            1      Winter           0            1
# 52 2012-02-22        3            1      Winter           0            1
# 53 2012-02-23        4            1      Winter           0            1
# 54 2012-02-24        5            1      Winter           0            1
# 55 2012-02-25        6            1      Winter           0            0
# 56 2012-02-26        0            1      Winter           0            0
# 57 2012-02-27        1            1      Winter           0            1
# 58 2012-02-28        2            1      Winter           0            1
# 59 2012-02-29        3            1      Winter           0            1
# 60 2012-03-01        4            1      Spring           0            1
# 61 2012-03-02        5            1      Spring           0            1
# ...

# %%
weather.season_desc[60:152] = 'Winter'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather[60:152]
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 60  2012-03-01        4            1      Winter           0            1
# 61  2012-03-02        5            1      Winter           0            1
# 62  2012-03-03        6            1      Winter           0            0
# 63  2012-03-04        0            1      Winter           0            0
# 64  2012-03-05        1            1      Winter           0            1
# 65  2012-03-06        2            1      Winter           0            1
# 66  2012-03-07        3            1      Winter           0            1
# 67  2012-03-08        4            1      Winter           0            1
# 68  2012-03-09        5            1      Winter           0            1
# 69  2012-03-10        6            1      Winter           0            0
# 70  2012-03-11        0            1      Winter           0            0
# 71  2012-03-12        1            1      Winter           0            1
# ...

# %%
weather.season_desc[60:152] = 'Spring'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather[60:152]
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 60  2012-03-01        4            1      Spring           0            1
# 61  2012-03-02        5            1      Spring           0            1
# 62  2012-03-03        6            1      Spring           0            0
# 63  2012-03-04        0            1      Spring           0            0
# 64  2012-03-05        1            1      Spring           0            1
# 65  2012-03-06        2            1      Spring           0            1
# 66  2012-03-07        3            1      Spring           0            1
# 67  2012-03-08        4            1      Spring           0            1
# 68  2012-03-09        5            1      Spring           0            1
# 69  2012-03-10        6            1      Spring           0            0
# 70  2012-03-11        0            1      Spring           0            0
# 71  2012-03-12        1            1      Spring           0            1
# ...

# %%
weather.season_desc[152:244] = 'Summer'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather[152:244]
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 152 2012-06-01        5            2      Summer           0            1
# 153 2012-06-02        6            2      Summer           0            0
# 154 2012-06-03        0            2      Summer           0            0
# 155 2012-06-04        1            2      Summer           0            1
# 156 2012-06-05        2            2      Summer           0            1
# 157 2012-06-06        3            2      Summer           0            1
# 158 2012-06-07        4            2      Summer           0            1
# 159 2012-06-08        5            2      Summer           0            1
# 160 2012-06-09        6            2      Summer           0            0
# 161 2012-06-10        0            2      Summer           0            0
# 162 2012-06-11        1            2      Summer           0            1
# 163 2012-06-12        2            2      Summer           0            1
# ...

# %%
weather.season_desc[244:334] = 'Fall'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather.season_desc[335] = 'Fall'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather.season_desc[334] = "Fall"
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather.season_desc[335:] = 'Winter'
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0   2012-01-01        0            1      Winter           0            0
# 1   2012-01-02        1            1      Winter           1            0
# 2   2012-01-03        2            1      Winter           0            1
# 3   2012-01-04        3            1      Winter           0            1
# 4   2012-01-05        4            1      Winter           0            1
# 5   2012-01-06        5            1      Winter           0            1
# 6   2012-01-07        6            1      Winter           0            0
# 7   2012-01-08        0            1      Winter           0            0
# 8   2012-01-09        1            1      Winter           0            1
# 9   2012-01-10        2            1      Winter           0            1
# 10  2012-01-11        3            1      Winter           0            1
# 11  2012-01-12        4            1      Winter           0            1
# ...

# %%
weather[300:]
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 300 2012-10-27        6            4        Fall           0            0
# 301 2012-10-28        0            4        Fall           0            0
# 302 2012-10-29        1            4        Fall           0            1
# 303 2012-10-30        2            4        Fall           0            1
# 304 2012-10-31        3            4        Fall           0            1
# 305 2012-11-01        4            4        Fall           0            1
# 306 2012-11-02        5            4        Fall           0            1
# 307 2012-11-03        6            4        Fall           0            0
# 308 2012-11-04        0            4        Fall           0            0
# 309 2012-11-05        1            4        Fall           0            1
# 310 2012-11-06        2            4        Fall           0            1
# 311 2012-11-07        3            4        Fall           0            1
# ...

# %%
weather.season_code[:60] = 4
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
C
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather.season_code[152:244] = 2
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather.season_code[244:335] = 3
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather.season_code[335:] = 4
# Out:
# /home/meslater/projects/data-science/lib/python2.7/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
weather
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 0   2012-01-01        0            4      Winter           0            0
# 1   2012-01-02        1            4      Winter           1            0
# 2   2012-01-03        2            4      Winter           0            1
# 3   2012-01-04        3            4      Winter           0            1
# 4   2012-01-05        4            4      Winter           0            1
# 5   2012-01-06        5            4      Winter           0            1
# 6   2012-01-07        6            4      Winter           0            0
# 7   2012-01-08        0            4      Winter           0            0
# 8   2012-01-09        1            4      Winter           0            1
# 9   2012-01-10        2            4      Winter           0            1
# 10  2012-01-11        3            4      Winter           0            1
# 11  2012-01-12        4            4      Winter           0            1
# ...

# %%
weather[80:105]
# Out:
#           date  weekday  season_code season_desc  is_holiday  is_work_day  \
# 80  2012-03-21        3            1      Spring           0            1
# 81  2012-03-22        4            1      Spring           0            1
# 82  2012-03-23        5            1      Spring           0            1
# 83  2012-03-24        6            1      Spring           0            0
# 84  2012-03-25        0            1      Spring           0            0
# 85  2012-03-26        1            1      Spring           0            1
# 86  2012-03-27        2            1      Spring           0            1
# 87  2012-03-28        3            1      Spring           0            1
# 88  2012-03-29        4            1      Spring           0            1
# 89  2012-03-30        5            1      Spring           0            1
# 90  2012-03-31        6            1      Spring           0            0
# 91  2012-04-01        0            1      Spring           0            0
# ...

# %% [markdown]
# Changed all season codes to be the right season

# %%
weather.pivot(index='season_desc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-4fe89f832bf1> in <module>()
# ----> 1 weather.pivot(index='season_desc')
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in pivot(self, index, columns, values)
#    3507         """
#    3508         from pandas.core.reshape import pivot
# -> 3509         return pivot(self, index=index, columns=columns, values=values)
#    3510
#    3511     def stack(self, level=-1, dropna=True):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/reshape.pyc in pivot(self, index, columns, values)
#     320     """
#     321     if values is None:
# --> 322         indexed = self.set_index([index, columns])
#     323         return indexed.unstack(columns)
#     324     else:
#
# ...

# %%
weather.pivot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-4189b2a4ab89> in <module>()
# ----> 1 weather.pivot()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in pivot(self, index, columns, values)
#    3507         """
#    3508         from pandas.core.reshape import pivot
# -> 3509         return pivot(self, index=index, columns=columns, values=values)
#    3510
#    3511     def stack(self, level=-1, dropna=True):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/reshape.pyc in pivot(self, index, columns, values)
#     320     """
#     321     if values is None:
# --> 322         indexed = self.set_index([index, columns])
#     323         return indexed.unstack(columns)
#     324     else:
#
# ...

# %%
weather.pivot(index='season_desc')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-4fe89f832bf1> in <module>()
# ----> 1 weather.pivot(index='season_desc')
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in pivot(self, index, columns, values)
#    3507         """
#    3508         from pandas.core.reshape import pivot
# -> 3509         return pivot(self, index=index, columns=columns, values=values)
#    3510
#    3511     def stack(self, level=-1, dropna=True):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/reshape.pyc in pivot(self, index, columns, values)
#     320     """
#     321     if values is None:
# --> 322         indexed = self.set_index([index, columns])
#     323         return indexed.unstack(columns)
#     324     else:
#
# ...

# %%
weather.groupby['season_desc'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-760fb3aec14b> in <module>()
# ----> 1 weather.groupby['season_desc'].mean()
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
weather.pivot_table(index='date', columns='season_desc' values='temp')
# Out:
#   File "<ipython-input-64-f1ddb05d23e2>", line 1
#     weather.pivot_table(index='date', columns='season_desc' values='temp')
#                                                                  ^
# SyntaxError: invalid syntax

# %%
weather.pivot(index='date', columns='season_desc' values='temp')
# Out:
#   File "<ipython-input-65-f10b69ca22e1>", line 1
#     weather.pivot(index='date', columns='season_desc' values='temp')
#                                                            ^
# SyntaxError: invalid syntax

# %%
weather.pivot_table(index='date', columns='season_desc', values='temp')
# Out:
# season_desc  Fall  Spring  Summer    Winter
# date
# 2012-01-01    NaN     NaN     NaN  0.370000
# 2012-01-02    NaN     NaN     NaN  0.273043
# 2012-01-03    NaN     NaN     NaN  0.150000
# 2012-01-04    NaN     NaN     NaN  0.107500
# 2012-01-05    NaN     NaN     NaN  0.265833
# 2012-01-06    NaN     NaN     NaN  0.334167
# 2012-01-07    NaN     NaN     NaN  0.393333
# 2012-01-08    NaN     NaN     NaN  0.337500
# 2012-01-09    NaN     NaN     NaN  0.224167
# 2012-01-10    NaN     NaN     NaN  0.308696
# 2012-01-11    NaN     NaN     NaN  0.274167
# 2012-01-12    NaN     NaN     NaN  0.382500
# 2012-01-13    NaN     NaN     NaN  0.274167
# 2012-01-14    NaN     NaN     NaN  0.180000
# 2012-01-15    NaN     NaN     NaN  0.166667
# 2012-01-16    NaN     NaN     NaN  0.190000
# 2012-01-17    NaN     NaN     NaN  0.373043
# 2012-01-18    NaN     NaN     NaN  0.303333
# 2012-01-19    NaN     NaN     NaN  0.190000
# 2012-01-20    NaN     NaN     NaN  0.217500
# ...

# %%
weather.pivot_table(index='season_desc', columns='temp', values=weather.groupby('season_desc')['temp'].mean)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-67-9446b743c733> in <module>()
# ----> 1 weather.pivot_table(index='season_desc', columns='temp', values=weather.groupby('season_desc')['temp'].mean)
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/tools/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna)
#     109
#     110     grouped = data.groupby(keys)
# --> 111     agged = grouped.agg(aggfunc)
#     112
#     113     table = agged
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in agg(self, func, *args, **kwargs)
#     683     @Appender(_agg_doc)
#     684     def agg(self, func, *args, **kwargs):
# --> 685         return self.aggregate(func, *args, **kwargs)
#     686
#     687     def _iterate_slices(self):
#
# ...

# %%
weather.groupby('season_desc')['temp'].mean
# Out:
# <bound method SeriesGroupBy.mean of <pandas.core.groupby.SeriesGroupBy object at 0x7fb1b34aebd0>>

# %%
weather.pivot_table(index='season_desc', columns='temp', values=weather.groupby('season_desc')['temp'].mean())
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-69-f8f7025923da> in <module>()
# ----> 1 weather.pivot_table(index='season_desc', columns='temp', values=weather.groupby('season_desc')['temp'].mean())
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/tools/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna)
#     109
#     110     grouped = data.groupby(keys)
# --> 111     agged = grouped.agg(aggfunc)
#     112
#     113     table = agged
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in agg(self, func, *args, **kwargs)
#     683     @Appender(_agg_doc)
#     684     def agg(self, func, *args, **kwargs):
# --> 685         return self.aggregate(func, *args, **kwargs)
#     686
#     687     def _iterate_slices(self):
#
# ...

# %%
weather.groupby('season_desc')['temp'].mean()
# Out:
# season_desc
# Fall      0.485572
# Spring    0.510645
# Summer    0.713505
# Winter    0.304227
# Name: temp, dtype: float64

# %% [markdown]
# Found average temp by season.  Numbers make sense

# %%
usage = pd.read_table('usage_2012.tsv')

# %%
usage[usage['time_start'] > 12-01-2012 00:00:00]
# Out:
#   File "<ipython-input-72-b06ef0ae057b>", line 1
#     usage[usage['time_start'] > 12-01-2012 00:00:00]
#                                             ^
# SyntaxError: invalid syntax

# %%
usage['time_start'] = pd.to_datetime(usage['time_start'])

# %%
usage['time_end'] = pd.to_datetime(usage['time_end'])

# %%
usage[usage['time_start'] > 12-01-2012 00:00:00]
# Out:
#   File "<ipython-input-75-b06ef0ae057b>", line 1
#     usage[usage['time_start'] > 12-01-2012 00:00:00]
#                                             ^
# SyntaxError: invalid syntax

# %%
usage[usage['time_start'] > 12-01-2012]
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
usage[usage['time_start'] > 2012-12-01]
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
usage.ix['2012-12-01': '2012-12-31']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-c244d42b8401> in <module>()
# ----> 1 usage.ix['2012-12-01': '2012-12-31']
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68             return self._getitem_tuple(key)
#      69         else:
# ---> 70             return self._getitem_axis(key, axis=0)
#      71
#      72     def _get_label(self, label, axis=0):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     906         labels = self.obj._get_axis(axis)
#     907         if isinstance(key, slice):
# --> 908             return self._get_slice_axis(key, axis=axis)
#     909         elif is_list_like_indexer(key) and not (isinstance(key, tuple) and
# ...

# %%
import datetime

# %%
st = datetime.datetime(2012, 12, 01, 0, 0)

# %%
end = datetime.datetime(2013, 01, 01 ,0 ,0)

# %%
usage.ix[st, end]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-647f851cd77a> in <module>()
# ----> 1 usage.ix[st, end]
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      66                 pass
#      67
# ---> 68             return self._getitem_tuple(key)
#      69         else:
#      70             return self._getitem_axis(key, axis=0)
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     698     def _getitem_tuple(self, tup):
#     699         try:
# --> 700             return self._getitem_lowerdim(tup)
#     701         except IndexingError:
#     702             pass
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
# ...

# %%
usage.ix[st:end]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-3f6f2ccd9c3e> in <module>()
# ----> 1 usage.ix[st:end]
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68             return self._getitem_tuple(key)
#      69         else:
# ---> 70             return self._getitem_axis(key, axis=0)
#      71
#      72     def _get_label(self, label, axis=0):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     906         labels = self.obj._get_axis(axis)
#     907         if isinstance(key, slice):
# --> 908             return self._get_slice_axis(key, axis=axis)
#     909         elif is_list_like_indexer(key) and not (isinstance(key, tuple) and
# ...

# %%
type(usage['time_start'][0])
# Out:
# pandas.tslib.Timestamp

# %%
usage['time_stamp'][datetime(2012, 01, 01):]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-f6563a6fef38> in <module>()
# ----> 1 usage['time_stamp'][datetime(2012, 01, 01):]
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
usage['time_start'][datetime(2012, 01, 01):]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-d6aa8d628ba6> in <module>()
# ----> 1 usage['time_start'][datetime(2012, 01, 01):]
#
# TypeError: 'module' object is not callable

# %%
import datetime

# %%
usage['time_start'][datetime(2012, 01, 01):]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-d6aa8d628ba6> in <module>()
# ----> 1 usage['time_start'][datetime(2012, 01, 01):]
#
# TypeError: 'module' object is not callable

# %%
usage['time_start'][datetime.datetime(2012, 01, 01):]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-d3060e1144c9> in <module>()
# ----> 1 usage['time_start'][datetime.datetime(2012, 01, 01):]
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     559             key = check_bool_indexer(self.index, key)
#     560
# --> 561         return self._get_with(key)
#     562
#     563     def _get_with(self, key):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/series.pyc in _get_with(self, key)
#     565         if isinstance(key, slice):
#     566             indexer = self.index._convert_slice_indexer(key, kind='getitem')
# --> 567             return self._get_values(indexer)
#     568         elif isinstance(key, ABCDataFrame):
# ...

# %%
usage['time_start'][datetime.datetime(2012, 02, 01):]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-16154b8c36ea> in <module>()
# ----> 1 usage['time_start'][datetime.datetime(2012, 02, 01):]
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     559             key = check_bool_indexer(self.index, key)
#     560
# --> 561         return self._get_with(key)
#     562
#     563     def _get_with(self, key):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/series.pyc in _get_with(self, key)
#     565         if isinstance(key, slice):
#     566             indexer = self.index._convert_slice_indexer(key, kind='getitem')
# --> 567             return self._get_values(indexer)
#     568         elif isinstance(key, ABCDataFrame):
# ...

# %%
usage[(usage['time_start'] > '2012-12-01 00:00:00') & (usage['time_start'] < '2012-12-31 23:00:00')]
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 2288811  W01275 2012-12-01 00:58:00 2012-12-01 01:11:00             13
# 2288812  W20172 2012-12-01 00:58:00 2012-12-01 01:06:00              8
# 2288813  W01366 2012-12-01 00:57:00 2012-12-01 00:59:00              2
# 2288814  W20050 2012-12-01 00:57:00 2012-12-01 01:02:00              5
# 2288815  W20944 2012-12-01 00:57:00 2012-12-01 01:03:00              6
# 2288816  W20175 2012-12-01 00:57:00 2012-12-01 01:07:00             10
# 2288817  W00479 2012-12-01 00:56:00 2012-12-01 01:02:00              6
# 2288818  W00343 2012-12-01 00:56:00 2012-12-01 01:01:00              5
# 2288819  W00872 2012-12-01 00:56:00 2012-12-01 01:02:00              6
# 2288820  W20165 2012-12-01 00:56:00 2012-12-01 01:09:00             13
# 2288821  W00318 2012-12-01 00:55:00 2012-12-01 01:06:00             11
# 2288822  W00295 2012-12-01 00:55:00 2012-12-01 01:11:00             16
# ...

# %%
pd.grouby(weather, by=[weather.time_start.month])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-7eb277233486> in <module>()
# ----> 1 pd.grouby(weather, by=[weather.time_start.month])
#
# AttributeError: 'module' object has no attribute 'grouby'

# %%
pd.groupby(weather, by=[weather.time_start.month])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-26c30d04e01c> in <module>()
# ----> 1 pd.groupby(weather, by=[weather.time_start.month])
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'time_start'

# %%
pd.groupby(weather, by=[weather['time_start'].month])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-034832725f5e> in <module>()
# ----> 1 pd.groupby(weather, by=[weather['time_start'].month])
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
pd.groupby(usage, by=[usage.time_start.month])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-c208f3458fe0> in <module>()
# ----> 1 pd.groupby(usage, by=[usage.time_start.month])
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
usage['time_start']=pd.to_datetime(usage['time_start'], format='%m/%d/%y %I:%M%p')

# %%
pd.groupby(usage, by=[usage.time_start.month])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-c208f3458fe0> in <module>()
# ----> 1 pd.groupby(usage, by=[usage.time_start.month])
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
usage.time_start.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-cae28a1e257d> in <module>()
# ----> 1 usage.time_start.month
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
usage
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
usage['time_start']=pd.to_datetime(usage['time_start'],format='%m/%d/%y %I:%M%p')

# %%
pd.groupby(usage,by=[usage.time_start.month,usage.time_start.year])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-c46b2ebbb473> in <module>()
# ----> 1 pd.groupby(usage,by=[usage.time_start.month,usage.time_start.year])
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'month'

# %%
usage.groupby(pd.TimeGrouper(freq='M'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-5a40fb73018c> in <module>()
# ----> 1 usage.groupby(pd.TimeGrouper(freq='M'))
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3157         axis = self._get_axis_number(axis)
#    3158         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3159                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3160
#    3161     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1197         raise TypeError('invalid type: %s' % type(obj))
#    1198
# -> 1199     return klass(obj, by, **kwds)
#    1200
# ...

# %%
usage.set_index('Date').groupby(pd.TimeGrouper('M')).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-a66782713ef8> in <module>()
# ----> 1 usage.set_index('Date').groupby(pd.TimeGrouper('M')).sum()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2605                 names.append(None)
#    2606             else:
# -> 2607                 level = frame[col].values
#    2608                 names.append(col)
#    2609                 if drop:
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# ...

# %%
usage.set_index('time_start').groupby(pd.TimeGrouper('M')).sum()
# Out:
#             duration_mins
# time_start
# 2012-01-31        2607534
# 2012-02-29        2756474
# 2012-03-31        6122610
# 2012-04-30        3401167
# 2012-05-31        3809210
# 2012-06-30        3833632
# 2012-07-31        3842818
# 2012-08-31        3721467
# 2012-09-30        3911300
# 2012-10-31        3345546
# 2012-11-30        2248404
# 2012-12-31        1690204

# %%
usage.set_index('time_start').groupby(pd.TimeGrouper('M')).count()
# Out:
#             bike_id  time_end  duration_mins  station_start  station_end  \
# time_start
# 2012-01-31   193180    193180         193180         186614       186820
# 2012-02-29   205958    205958         205958         199040       199380
# 2012-03-31   329308    329308         329308         319274       319684
# 2012-04-30   173954    173954         173954         172015       172005
# 2012-05-31   195638    195638         195638         193580       193548
# 2012-06-30   202600    202600         202600         200341       200390
# 2012-07-31   203607    203607         203607         201425       201445
# 2012-08-31   214503    214503         214503         212215       212178
# 2012-09-30   218573    218573         218573         216480       216486
# 2012-10-31   198841    198841         198841         196906       196952
# 2012-11-30   152649    152649         152649         151128       151144
# 2012-12-31   123713    123713         123713         122479       122452
#
# ...

# %%
usage.set_index('time_start').groupby(pd.TimeGrouper('M')).size()
# Out:
# time_start
# 2012-01-31    193180
# 2012-02-29    205958
# 2012-03-31    329308
# 2012-04-30    173954
# 2012-05-31    195638
# 2012-06-30    202600
# 2012-07-31    203607
# 2012-08-31    214503
# 2012-09-30    218573
# 2012-10-31    198841
# 2012-11-30    152649
# 2012-12-31    123713
# Freq: M, dtype: int64

# %% [markdown]
# We have grouped by month and counted the rows

# %%
usage.set_index('time_start').groupby(pd.TimeGrouper('3M')).size()
# Out:
# time_start
# 2012-01-31    193180
# 2012-04-30    709220
# 2012-07-31    601845
# 2012-10-31    631917
# 2013-01-31    276362
# Freq: 3M, dtype: int64

# %%
uw = pd.merge(usage, weather, left_on='time_start', right_on='date')

# %%
uw
# Out:
#     bike_id time_start            time_end  duration_mins  \
# 0    W00987 2012-01-02 2012-01-02 00:11:00             11
# 1    W00987 2012-01-02 2012-01-02 00:11:00             11
# 2    W01453 2012-01-07 2012-01-07 00:08:00              8
# 3    W01453 2012-01-07 2012-01-07 00:08:00              8
# 4    W00404 2012-01-08 2012-01-08 00:03:00              3
# 5    W00404 2012-01-08 2012-01-08 00:03:00              3
# 6    W01487 2012-01-13 2012-01-13 00:08:00              8
# 7    W01487 2012-01-13 2012-01-13 00:08:00              8
# 8    W00570 2012-01-14 2012-01-14 00:05:00              5
# 9    W00570 2012-01-14 2012-01-14 00:05:00              5
# 10   W01487 2012-01-21 2012-01-21 00:04:00              4
# 11   W01487 2012-01-21 2012-01-21 00:04:00              4
# 12   W00816 2012-01-24 2012-01-24 00:03:00              3
# 13   W00816 2012-01-24 2012-01-24 00:03:00              3
# 14   W01038 2012-01-27 2012-01-27 00:06:00              6
# ...

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('3M')).size()
# Out:
# time_start
# 2012-01-31     30
# 2012-04-30    142
# 2012-07-31    134
# 2012-10-31    135
# 2013-01-31     63
# Freq: 3M, dtype: int64

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M')).size()
# Out:
# time_start
# 2012-01-31    30
# 2012-02-29    44
# 2012-03-31    54
# 2012-04-30    44
# 2012-05-31    39
# 2012-06-30    47
# 2012-07-31    48
# 2012-08-31    51
# 2012-09-30    41
# 2012-10-31    43
# 2012-11-30    39
# 2012-12-31    24
# Freq: M, dtype: int64

# %%
uw = pd.merge(usage, weather, left_on='time_start', right_on='date', how='outer')

# %%
uw
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 2        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 4        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 5        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 6        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 7        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 8        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 9        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 10       W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 11       W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# ...

# %%
uw
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 2        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 4        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 5        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 6        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 7        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 8        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 9        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 10       W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 11       W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# ...

# %%
usage['date']=pd.to_datetime(usage['time_start'],format='%m/%d/%y')

# %%
usage
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
pd.to_datetime(usage['time_start'][0], format='%m/%d/%y')
# Out:
# Timestamp('2012-01-01 00:04:00')

# %%
pd.to_datetime(usage['time_start'][0], format=%m/%d/%y)
# Out:
#   File "<ipython-input-118-49b7c21c05cb>", line 1
#     pd.to_datetime(usage['time_start'][0], format=%m/%d/%y)
#                                                   ^
# SyntaxError: invalid syntax

# %%
pd.to_datetime(usage['time_start'][0], format='%y')
# Out:
# Timestamp('2012-01-01 00:04:00')

# %%
usage['time_start'][0].dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-b9517b2c2c4f> in <module>()
# ----> 1 usage['time_start'][0].dt.date
#
# AttributeError: 'Timestamp' object has no attribute 'dt'

# %%
usage['time_start'].dt.date
# Out:
# 0          2012-01-01
# 1          2012-01-01
# 2          2012-01-01
# 3          2012-01-01
# 4          2012-01-01
# 5          2012-01-01
# 6          2012-01-01
# 7          2012-01-01
# 8          2012-01-01
# 9          2012-01-01
# 10         2012-01-01
# 11         2012-01-01
# 12         2012-01-01
# 13         2012-01-01
# 14         2012-01-01
# 15         2012-01-01
# 16         2012-01-01
# 17         2012-01-01
# 18         2012-01-01
# 19         2012-01-01
# 20         2012-01-01
# 21         2012-01-01
# 22         2012-01-01
# 23         2012-01-01
# 24         2012-01-01
# 25         2012-01-01
# 26         2012-01-01
# 27         2012-01-01
# 28         2012-01-01
# 29         2012-01-01
#               ...
# 2412494    2012-12-31
# 2412495    2012-12-31
# 2412496    2012-12-31
# 2412497    2012-12-31
# 2412498    2012-12-31
# 2412499    2012-12-31
# 2412500    2012-12-31
# 2412501    2012-12-31
# 2412502    2012-12-31
# 2412503    2012-12-31
# ...

# %%
usage
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
usage
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
usage['date'] = usage['time_start'].dt.date

# %%
usage
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
uw = pd.merge(usage, weather, left_on='date', right_on='date', how='outer')

# %%
uw
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
type(usage['date'])
# Out:
# pandas.core.series.Series

# %%
type(usage['date'][0])
# Out:
# datetime.date

# %%
type(weather['date'][0])
# Out:
# pandas.tslib.Timestamp

# %%
weather['date'] = weather['time_start'].dt.date
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-a049f9100596> in <module>()
# ----> 1 weather['date'] = weather['time_start'].dt.date
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
weather['date'] = weather['date'].dt.date

# %%
type(weather['date'][0])
# Out:
# datetime.date

# %%
uw = pd.merge(usage, weather, left_on='date', right_on='date', how='outer')

# %%
uw
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %% [markdown]
# merged the two tables on date

# %%
uw.set_index('temp').groupby(pd.TimeGrouper('M')).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-f006d6c58adb> in <module>()
# ----> 1 uw.set_index('temp').groupby(pd.TimeGrouper('M')).mean()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3157         axis = self._get_axis_number(axis)
#    3158         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3159                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3160
#    3161     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1197         raise TypeError('invalid type: %s' % type(obj))
#    1198
# ...

# %%
uw.set_index('date').groupby(pd.TimeGrouper('M')).size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-174422cb5357> in <module>()
# ----> 1 uw.set_index('date').groupby(pd.TimeGrouper('M')).size()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3157         axis = self._get_axis_number(axis)
#    3158         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3159                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3160
#    3161     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1197         raise TypeError('invalid type: %s' % type(obj))
#    1198
# ...

# %%
uw.set_index('start_time').groupby(pd.TimeGrouper('M')).size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-a35f013a1c8c> in <module>()
# ----> 1 uw.set_index('start_time').groupby(pd.TimeGrouper('M')).size()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2605                 names.append(None)
#    2606             else:
# -> 2607                 level = frame[col].values
#    2608                 names.append(col)
#    2609                 if drop:
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# ...

# %%
uw
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M')).size()
# Out:
# time_start
# 2012-01-31    193180
# 2012-02-29    205958
# 2012-03-31    329308
# 2012-04-30    173954
# 2012-05-31    195638
# 2012-06-30    202600
# 2012-07-31    203607
# 2012-08-31    214503
# 2012-09-30    218573
# 2012-10-31    198841
# 2012-11-30    152649
# 2012-12-31    123713
# Freq: M, dtype: int64

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-656c6f4a1790> in <module>()
# ----> 1 uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().size()
#
# TypeError: 'int' object is not callable

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().reset_index().groupby(pd.TimeGrouper('M')).size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-ee9ee6c13dd1> in <module>()
# ----> 1 uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().reset_index().groupby(pd.TimeGrouper('M')).size()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3157         axis = self._get_axis_number(axis)
#    3158         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3159                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3160
#    3161     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
# ...

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().reset_index('time_start').groupby(pd.TimeGrouper('M')).size(
# Out:
#   File "<ipython-input-144-a00d495e58d0>", line 1
#     uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().reset_index('time_start').groupby(pd.TimeGrouper('M')).size(
#                                                                                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().reset_index('time_start').groupby(pd.TimeGrouper('M')).size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-95aa1f2c49ac> in <module>()
# ----> 1 uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean().reset_index('time_start').groupby(pd.TimeGrouper('M')).size()
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3157         axis = self._get_axis_number(axis)
#    3158         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 3159                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    3160
#    3161     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
# ...

# %%
weather_rides = uw.pivot_table(index='date', columns='bike_id', values='temp', aggfunc=np.mean, fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-d548a0bff3c4> in <module>()
# ----> 1 weather_rides = uw.pivot_table(index='date', columns='bike_id', values='temp', aggfunc=np.mean, fill_value=0)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
weather_rides = uw.pivot_table(index='date', columns='bike_id', values='temp', aggfunc=np.mean, fill_value=0)

# %%
weather_rides
# Out:
# bike_id       W00005    W00006    W00007    W00008    W00009    W00010  \
# date
# 2012-01-01  0.370000  0.000000  0.370000  0.370000  0.000000  0.000000
# 2012-01-02  0.000000  0.000000  0.273043  0.273043  0.273043  0.000000
# 2012-01-03  0.000000  0.150000  0.000000  0.000000  0.150000  0.000000
# 2012-01-04  0.000000  0.000000  0.000000  0.107500  0.107500  0.000000
# 2012-01-05  0.000000  0.265833  0.265833  0.000000  0.000000  0.000000
# 2012-01-06  0.334167  0.334167  0.334167  0.334167  0.334167  0.000000
# 2012-01-07  0.393333  0.393333  0.000000  0.393333  0.393333  0.000000
# 2012-01-08  0.337500  0.337500  0.000000  0.337500  0.000000  0.000000
# 2012-01-09  0.224167  0.224167  0.224167  0.224167  0.224167  0.000000
# 2012-01-10  0.308696  0.308696  0.000000  0.000000  0.308696  0.000000
# 2012-01-11  0.274167  0.274167  0.000000  0.274167  0.274167  0.000000
# 2012-01-12  0.382500  0.000000  0.000000  0.382500  0.382500  0.000000
# ...

# %%
uw.set_index('time_start').groupby(pd.TimeGrouper('M')).size()
# Out:
# time_start
# 2012-01-31    193180
# 2012-02-29    205958
# 2012-03-31    329308
# 2012-04-30    173954
# 2012-05-31    195638
# 2012-06-30    202600
# 2012-07-31    203607
# 2012-08-31    214503
# 2012-09-30    218573
# 2012-10-31    198841
# 2012-11-30    152649
# 2012-12-31    123713
# Freq: M, dtype: int64

# %%
size = uw.set_index('time_start').groupby(pd.TimeGrouper('M')).size()

# %%
temp = uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['temp'].mean()

# %%
temp_size = pd.merge(size, temp, left_on='time_start', right_on='time_start')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-99b167db0dca> in <module>()
# ----> 1 temp_size = pd.merge(size, temp, left_on='time_start', right_on='time_start')
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy)
#      35                          right_on=right_on, left_index=left_index,
#      36                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 37                          copy=copy)
#      38     return op.get_result()
#      39 if __debug__:
#
# /home/meslater/projects/data-science/local/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy)
# ...

# %%
temp
# Out:
# time_start
# 2012-01-31    0.290846
# 2012-02-29    0.327514
# 2012-03-31    0.465777
# 2012-04-30    0.477665
# 2012-05-31    0.612952
# 2012-06-30    0.671553
# 2012-07-31    0.751041
# 2012-08-31    0.713106
# 2012-09-30    0.616453
# 2012-10-31    0.511315
# 2012-11-30    0.341375
# 2012-12-31    0.344421
# Freq: M, Name: temp, dtype: float64

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
type(size)
# Out:
# pandas.core.series.Series

# %%
temp_size = DataFrame({'temp': temp, 'size': size})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-7dc869ab8bc4> in <module>()
# ----> 1 temp_size = DataFrame({'temp': temp, 'size': size})
#
# NameError: name 'DataFrame' is not defined

# %%
temp_size = pd.DataFrame({'temp': temp, 'size': size})

# %%
temp_size
# Out:
#               size      temp
# time_start
# 2012-01-31  193180  0.290846
# 2012-02-29  205958  0.327514
# 2012-03-31  329308  0.465777
# 2012-04-30  173954  0.477665
# 2012-05-31  195638  0.612952
# 2012-06-30  202600  0.671553
# 2012-07-31  203607  0.751041
# 2012-08-31  214503  0.713106
# 2012-09-30  218573  0.616453
# 2012-10-31  198841  0.511315
# 2012-11-30  152649  0.341375
# 2012-12-31  123713  0.344421

# %% [markdown]
# ta da!  created a new dataframe from two series

# %%
season = uw.groupby('season_desc')

# %%
season

# %%
season = uw.groupby('season_desc').size()

# %%
season
# Out:
# season_desc
# Fall      570063
# Spring    698900
# Summer    620710
# Winter    522851
# dtype: int64

# %%
temperature = uw.groupby('season_desc')['temp'].mean()

# %%
temperature
# Out:
# season_desc
# Fall      0.506121
# Spring    0.509933
# Summer    0.711987
# Winter    0.317967
# Name: temp, dtype: float64

# %%
temp_season = pd.DataFrame({'temperature': temperature, 'season': season})

# %%
temp_season
# Out:
#              season  temperature
# season_desc
# Fall         570063     0.506121
# Spring       698900     0.509933
# Summer       620710     0.711987
# Winter       522851     0.317967

# %%
uw
# Out:
#         bike_id          time_start            time_end  duration_mins  \
# 0        W01412 2012-01-01 00:04:00 2012-01-01 00:11:00              7
# 1        W00524 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 2        W00235 2012-01-01 00:10:00 2012-01-01 00:29:00             19
# 3        W00864 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 4        W00995 2012-01-01 00:15:00 2012-01-01 00:23:00              8
# 5        W00466 2012-01-01 00:17:00 2012-01-01 00:23:00              6
# 6        W00525 2012-01-01 00:18:00 2012-01-01 00:47:00             29
# 7        W00340 2012-01-01 00:22:00 2012-01-01 00:27:00              5
# 8        W00466 2012-01-01 00:24:00 2012-01-01 00:33:00              9
# 9        W00963 2012-01-01 00:25:00 2012-01-01 00:40:00             15
# 10       W01398 2012-01-01 00:29:00 2012-01-01 00:48:00             19
# 11       W00042 2012-01-01 00:30:00 2012-01-01 00:38:00              8
# ...

# %%
casual = uw.groupby('no_casual_riders').mean()

# %%
casual
# Out:
#                   duration_mins   weekday  season_code  is_holiday  \
# no_casual_riders
# 2                      9.681818  1.000000     3.000000           0
# 9                      9.217687  3.000000     4.000000           0
# 65                    10.449426  3.000000     4.000000           0
# 67                    12.840000  6.000000     4.000000           0
# 73                    10.036625  0.000000     4.000000           0
# 74                    11.936333  4.000000     4.000000           0
# 87                    10.829380  2.000000     3.000000           0
# 89                    10.370802  2.000000     4.000000           0
# 92                    11.035879  3.000000     4.000000           0
# 94                    10.836502  1.000000     4.000000           0
# 95                     9.737643  3.000000     4.000000           0
# 106                   10.880169  1.000000     4.000000           0
# 109                   11.192408  3.000000     4.000000           0
# ...

# %%
cust_type = uw.groupby('cust_type').size()

# %%
cust_type
# Out:
# cust_type
# Casual         421958
# Registered    1584150
# Subscriber     406416
# dtype: int64

# %%
cust_type = uw.set_index('time_start').groupby(pd.TimeGrouper('M'))['cust_type'].size()

# %%
cust_type
# Out:
# time_start
# 2012-01-31    193180
# 2012-02-29    205958
# 2012-03-31    329308
# 2012-04-30    173954
# 2012-05-31    195638
# 2012-06-30    202600
# 2012-07-31    203607
# 2012-08-31    214503
# 2012-09-30    218573
# 2012-10-31    198841
# 2012-11-30    152649
# 2012-12-31    123713
# Freq: M, dtype: int64

# %%
cust_type = uw.pivot_table(index='season_desc', columns='cust_type', values='temp', aggfunc=np.mean)

# %%
cust_type
# Out:
# cust_type      Casual  Registered  Subscriber
# season_desc
# Fall         0.524714    0.615749    0.435132
# Spring       0.521518    0.506878         NaN
# Summer       0.710692    0.712324         NaN
# Winter       0.321836    0.309009    0.345765

# %%
cust_type = uw.pivot_table(index='season_desc', columns='cust_type', values='temp', aggfunc=np.count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-ba3118fe9c90> in <module>()
# ----> 1 cust_type = uw.pivot_table(index='season_desc', columns='cust_type', values='temp', aggfunc=np.count)
#
# AttributeError: 'module' object has no attribute 'count'

# %%
cust_type = uw.pivot_table(index='season_desc', columns='cust_type', values='temp', aggfunc=np.size)

# %%
cust_type
# Out:
# cust_type    Casual  Registered  Subscriber
# season_desc
# Fall          99320      174795      295948
# Spring       145883      553017         NaN
# Summer       128176      492534         NaN
# Winter        48579      363804      110468

# %% [markdown]
# Now we know that subscribers do not subscrie in Spring or Summer!
